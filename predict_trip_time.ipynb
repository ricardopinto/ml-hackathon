# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import datetime

# %%
# prepare dataset by merging weather data into trip data

df_trips = pd.read_csv('trip.csv', index_col='trip_id', parse_dates=['starttime', 'stoptime'])
df_trips.head()

df_weather = pd.read_csv('weather.csv', index_col='Date', parse_dates=['Date'])
df_weather.head()
# Out:
# array(['Max_Temperature_F', 'Mean_Temperature_F', 'Min_TemperatureF',
#        'Max_Dew_Point_F', 'MeanDew_Point_F', 'Min_Dewpoint_F',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_Pressure_In', 'Mean_Sea_Level_Pressure_In',
#        'Min_Sea_Level_Pressure_In', 'Max_Visibility_Miles',
#        'Mean_Visibility_Miles', 'Min_Visibility_Miles',
#        'Max_Wind_Speed_MPH', 'Mean_Wind_Speed_MPH', 'Max_Gust_Speed_MPH',
#        'Precipitation_In', 'Events'], dtype=object)

# %%
weather_cols = df_weather.columns.drop(['Events', 'Max_Gust_Speed_MPH']).values
weather_cols
# Out:
# array(['Max_Temperature_F', 'Mean_Temperature_F', 'Min_TemperatureF',
#        'Max_Dew_Point_F', 'MeanDew_Point_F', 'Min_Dewpoint_F',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_Pressure_In', 'Mean_Sea_Level_Pressure_In',
#        'Min_Sea_Level_Pressure_In', 'Max_Visibility_Miles',
#        'Mean_Visibility_Miles', 'Min_Visibility_Miles',
#        'Max_Wind_Speed_MPH', 'Mean_Wind_Speed_MPH', 'Precipitation_In'], dtype=object)

# %%
df = df_trips.copy()
df['Date'] = df['starttime'].apply(lambda x: datetime.date(year=x.year, month=x.month, day=x.day).isoformat())

# %%
df[weather_cols] = df['Date'].apply(lambda d: df_weather.loc[d,weather_cols])

# %%
df.head()
# Out:
#                   starttime            stoptime    bikeid  tripduration  \
# trip_id
# 431     2014-10-13 10:31:00 2014-10-13 10:48:00  SEA00298       985.935
# 432     2014-10-13 10:32:00 2014-10-13 10:48:00  SEA00195       926.375
# 433     2014-10-13 10:33:00 2014-10-13 10:48:00  SEA00486       883.831
# 434     2014-10-13 10:34:00 2014-10-13 10:48:00  SEA00333       865.937
# 435     2014-10-13 10:34:00 2014-10-13 10:49:00  SEA00202       923.923
#
#            from_station_name  \
# trip_id
# 431      2nd Ave & Spring St
# 432      2nd Ave & Spring St
# 433      2nd Ave & Spring St
# 434      2nd Ave & Spring St
# 435      2nd Ave & Spring St
#
#                                            to_station_name from_station_id  \
# trip_id
# 431      Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 432      Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 433      Occidental Park / Occidental Ave S & S Washing...          CBD-06
# ...

# %%
df_weather.loc['2014-10-13':'2014-10-15',weather_cols]
# Out:
#             Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# Date
# 2014-10-13                 71                62.0                54
# 2014-10-14                 63                59.0                55
# 2014-10-15                 62                58.0                54
#
#             Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# Date
# 2014-10-13               55               51              46            87
# 2014-10-14               52               51              50            88
# 2014-10-15               53               50              46            87
#
#             Mean_Humidity  Min_Humidity  Max_Sea_Level_Pressure_In  \
# Date
# 2014-10-13             68            46                      30.03
# 2014-10-14             78            63                      29.84
# 2014-10-15             77            67                      29.98
#
#             Mean_Sea_Level_Pressure_In  Min_Sea_Level_Pressure_In  \
# Date
# ...

# %%
df.columns
# Out:
# Index(['starttime', 'stoptime', 'bikeid', 'tripduration', 'from_station_name',
#        'to_station_name', 'from_station_id', 'to_station_id', 'usertype',
#        'gender', 'birthyear', 'Date', 'Max_Temperature_F',
#        'Mean_Temperature_F', 'Min_TemperatureF', 'Max_Dew_Point_F',
#        'MeanDew_Point_F', 'Min_Dewpoint_F', 'Max_Humidity', 'Mean_Humidity',
#        'Min_Humidity', 'Max_Sea_Level_Pressure_In',
#        'Mean_Sea_Level_Pressure_In', 'Min_Sea_Level_Pressure_In',
#        'Max_Visibility_Miles', 'Mean_Visibility_Miles', 'Min_Visibility_Miles',
#        'Max_Wind_Speed_MPH', 'Mean_Wind_Speed_MPH', 'Precipitation_In'],
#       dtype='object')

# %%
features = df.drop([
    'Date',
    'gender',
    'tripduration',
    'starttime',
    'stoptime',
    'bikeid',
    'from_station_name',
    'to_station_name',
    'from_station_id',
    'to_station_id',
    'usertype',
    'gender',
    'birthyear'
], axis=1).columns.values

target = 'tripduration'
validation_split = 0.2
dataset_size = df.shape[0]
features
# Out:
# array(['Max_Temperature_F', 'Mean_Temperature_F', 'Min_TemperatureF',
#        'Max_Dew_Point_F', 'MeanDew_Point_F', 'Min_Dewpoint_F',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_Pressure_In', 'Mean_Sea_Level_Pressure_In',
#        'Min_Sea_Level_Pressure_In', 'Max_Visibility_Miles',
#        'Mean_Visibility_Miles', 'Min_Visibility_Miles',
#        'Max_Wind_Speed_MPH', 'Mean_Wind_Speed_MPH', 'Precipitation_In'], dtype=object)

# %%
df_train  = df.copy()
df_train = df_train[features]
df_train = df_train.fillna(df_train.mean())

# %%
x_train = df_train.as_matrix()
y_train = df[target].values

# %%
n_cols = len(features)  # or x_train.shape[1]
input_shape = (n_cols,)

# Specify the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape = input_shape))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='relu'))


# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Define early_stopping_monitor
early_stopping_monitor = EarlyStopping(patience=5)

# Fit the model
model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=validation_split
    #callbacks=[early_stopping_monitor]
)
# Out:
# 188852/188852 [==============================] - 26s - loss: 4072444.3414 - acc: 0.0000e+00 - val_loss: 4875077.6153 - val_acc: 0.0000e+00
# Epoch 9/10
# 188852/188852 [==============================] - 24s - loss: 4071729.3741 - acc: 0.0000e+00 - val_loss: 4883163.4959 - val_acc: 0.0000e+00
# Epoch 10/10
# 188852/188852 [==============================] - 23s - loss: 4070616.5980 - acc: 0.0000e+00 - val_loss: 4877322.5429 - val_acc: 0.0000e+00

# %%
pred = model.predict(np.array([df_train.iloc[0]])) # 985
pred[:,0][0]
# Out:
# 1184.9451

# %%
pred = model.predict(np.array([df_train.iloc[10]])) # 564
pred[:,0][0]
# Out:
# 1184.9451
